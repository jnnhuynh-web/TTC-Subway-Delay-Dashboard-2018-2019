# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

df = pd.read_csv('../Data/ttc_subway_delay_2018_2019_for_machine_learning.csv')
df.head()
# Out:
#    id        date  time      day                station   code  min_delay  \
# 0   1  2019-01-01  3:03  Tuesday         DUPONT STATION  MUATC         11
# 1   2  2019-01-01  3:08  Tuesday  EGLINTON WEST STATION  EUATC         11
# 2   3  2019-01-01  3:09  Tuesday         DUPONT STATION  EUATC          6
# 3   4  2019-01-01  3:26  Tuesday  ST CLAIR WEST STATION  EUATC          4
# 4   5  2019-01-01  8:04  Tuesday     DAVISVILLE STATION  MUNOA          5
#
#    min_gap bound line  vehicle  \
# 0       16     N   YU     6061
# 1       16     S   YU     5656
# 2       11     N   YU     5381
# 3        9     N   YU     5571
# 4       10     S   YU        0
#
#                                            code_info   latitude  longitude  \
# 0                                        ATC Project  43.674584 -79.406830
# 1                                 ATC RC&S Equipment  43.699209 -79.435819
# 2                                 ATC RC&S Equipment  43.674584 -79.406830
# 3                                 ATC RC&S Equipment  43.683888 -79.415113
# 4  No Operator Immediately Available - Not E.S.A....  43.697778 -79.397222
#
#                   line_name    month  time_range  month_number  hour  year
# 0  Yonge University Spadina  January  9PM-1:30AM             1     3  2019
# 1  Yonge University Spadina  January  9PM-1:30AM             1     3  2019
# 2  Yonge University Spadina  January  9PM-1:30AM             1     3  2019
# 3  Yonge University Spadina  January  9PM-1:30AM             1     3  2019
# 4  Yonge University Spadina  January       5-9AM             1     8  2019

# %%
df.columns
# Out:
# Index(['id', 'date', 'time', 'day', 'station', 'code', 'min_delay', 'min_gap',
#        'bound', 'line', 'vehicle', 'code_info', 'latitude', 'longitude',
#        'line_name', 'month', 'time_range', 'month_number', 'hour', 'year'],
#       dtype='object')

# %%
df = df.loc[df["station"]=="SHEPPARD WEST STATION"]
df.head()
# Out:
#       id        date   time        day                station   code  \
# 13    14  2019-01-01   8:44    Tuesday  SHEPPARD WEST STATION  TUNIP
# 23    24  2019-01-02   6:18  Wednesday  SHEPPARD WEST STATION   EUDO
# 80    82  2019-01-05  14:39   Saturday  SHEPPARD WEST STATION  TUNIP
# 98   100  2019-01-07  11:51     Monday  SHEPPARD WEST STATION  TUNIP
# 102  104  2019-01-07  16:17     Monday  SHEPPARD WEST STATION   MUIR
#
#      min_delay  min_gap bound line  vehicle  \
# 13           4        9     N   YU     5436
# 23           4       12     N   YU     5456
# 80           3        6     N   YU     5551
# 98           3        6     N   YU     5931
# 102          5        7     S   YU     6101
#
#                                              code_info   latitude  longitude  \
# 13                            Operator Not In Position  43.749444 -79.461944
# 23                    Door Problems - Faulty Equipment  43.749444 -79.461944
# 80                            Operator Not In Position  43.749444 -79.461944
# 98                            Operator Not In Position  43.749444 -79.461944
# 102  Injured or ill Customer (On Train) - Medical A...  43.749444 -79.461944
#
#                     line_name    month time_range  month_number  hour  year
# 13   Yonge University Spadina  January      5-9AM             1     8  2019
# 23   Yonge University Spadina  January      5-9AM             1     6  2019
# 80   Yonge University Spadina  January     12-3PM             1    14  2019
# 98   Yonge University Spadina  January   9AM-12PM             1    11  2019
# 102  Yonge University Spadina  January      3-6PM             1    16  2019

# %%
#df_selected = df[["station","bound","line","month_number","hour","year"]]
#df_selected = df[["station","bound","day","hour"]]
#df_selected = df[["station","bound","month_number","hour","year","day_number"]]
#df_selected = df[["station","month_number","hour"]]
df_selected = df[["code","day","month_number","hour"]]
df_selected.head()
# Out:
#       code        day  month_number  hour
# 13   TUNIP    Tuesday             1     8
# 23    EUDO  Wednesday             1     6
# 80   TUNIP   Saturday             1    14
# 98   TUNIP     Monday             1    11
# 102   MUIR     Monday             1    16

# %%
# Assign the data to X and y

X_NoEncoded = df_selected
y = df["min_delay"].values.reshape(-1, 1)
print(X_NoEncoded.shape, y.shape)
# Out:
# (650, 4) (650, 1)

# %% [markdown]
# GET DUMMIES ALL

# %%
X = pd.get_dummies(X_NoEncoded)
X.head()
# Out:
#      month_number  hour  code_EUAC  code_EUATC  code_EUBK  code_EUBO  \
# 13              1     8          0           0          0          0
# 23              1     6          0           0          0          0
# 80              1    14          0           0          0          0
# 98              1    11          0           0          0          0
# 102             1    16          0           0          0          0
#
#      code_EUCD  code_EUDO  code_EUECD  code_EULV  ...  code_TUS  code_TUSC  \
# 13           0          0           0          0  ...         0          0
# 23           0          1           0          0  ...         0          0
# 80           0          0           0          0  ...         0          0
# 98           0          0           0          0  ...         0          0
# 102          0          0           0          0  ...         0          0
#
#      code_TUSUP  day_Friday  day_Monday  day_Saturday  day_Sunday  \
# 13            0           0           0             0           0
# 23            0           0           0             0           0
# 80            0           0           0             1           0
# 98            0           0           1             0           0
# 102           0           0           1             0           0
#
#      day_Thursday  day_Tuesday  day_Wednesday
# 13              0            1              0
# 23              0            0              1
# 80              0            0              0
# 98              0            0              0
# 102             0            0              0
#
# [5 rows x 74 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

print(X_train.shape, y_train.shape)
# Out:
# (487, 74) (487, 1)

# %% [markdown]
# StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
#--> FOR SCALED!!

# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
### END SOLUTION
training_score = model.score(X_train_scaled, y_train_scaled)
testing_score = model.score(X_test_scaled, y_test_scaled)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.3121073451885641
# Testing Score: -6.6300264078098014e+25

# %%
# Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION
