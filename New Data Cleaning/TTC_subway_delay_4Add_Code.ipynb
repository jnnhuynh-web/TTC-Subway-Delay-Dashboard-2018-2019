# %%
import pandas as pd
import numpy as np

# %%
df1819Clean = pd.read_csv('Data20182019_No0_CleanFinal.csv')
len(df1819Clean)
# Out:
# 13727

# %%
df1819Clean.head()
# Out:
#          date   time      day                station   code  min_delay  \
# 0  2019-01-01  03:03  Tuesday         DUPONT STATION  MUATC         11
# 1  2019-01-01  03:08  Tuesday  EGLINTON WEST STATION  EUATC         11
# 2  2019-01-01  03:09  Tuesday         DUPONT STATION  EUATC          6
# 3  2019-01-01  03:26  Tuesday  ST CLAIR WEST STATION  EUATC          4
# 4  2019-01-01  08:04  Tuesday     DAVISVILLE STATION  MUNOA          5
#
#    min_gap bound line  vehicle
# 0       16     N   YU     6061
# 1       16     S   YU     5656
# 2       11     N   YU     5381
# 3        9     N   YU     5571
# 4       10     S   YU        0

# %%
df1819Clean['id'] = df1819Clean.index +1
df1819Clean.dtypes
# Out:
# date         object
# time         object
# day          object
# station      object
# code         object
# min_delay     int64
# min_gap       int64
# bound        object
# line         object
# vehicle       int64
# id            int64
# dtype: object

# %%
len(df1819Clean)
# Out:
# 13727

# %%
df_Code_Info = pd.read_excel('LookUp_Code_Info.xlsx')
df_Code_Info.head()
# Out:
#     code            code_info
# 0   EUAC     Air Conditioning
# 1   EUAL  Alternating Current
# 2  EUATC   ATC RC&S Equipment
# 3   EUBK               Brakes
# 4   EUBO                 Body

# %%
temp_info = df_Code_Info.loc[df_Code_Info['code'] == "PUEO"]
len(temp_info)
# Out:
# 0

# %%
temp_info = df_Code_Info.loc[df_Code_Info['code'] == "PUTDN"]
len(temp_info)
# Out:
# 1

# %%
temp = df1819Clean.loc[df1819Clean['code'] == "PUEO"]
len(temp)
#MUPF, PUEO, PUEWZ, PUEME
# Out:
# 19

# %%
temp = df1819Clean.loc[df1819Clean['code'] == "PUEME"]
len(temp)
# Out:
# 1

# %%
temp = df1819Clean.loc[df1819Clean['code'] == "MUPF"]
len(temp)
# Out:
# 5

# %%
temp = df1819Clean.loc[df1819Clean['code'] == "PUEME"]
len(temp)
# Out:
# 1

# %%
temp = df1819Clean.loc[df1819Clean['code'] == "PUTDN"]
len(temp)
# Out:
# 32

# %%
df_Code_Info_eu = df_Code_Info[df_Code_Info["code"].str.contains('EU')]
#df_Code_Info_eu

# %%
df1819Clean_codes = df1819Clean.code.unique()
series1819Clean_codes = pd.Series(df1819Clean_codes)
#series1819Clean_codes.str.contains('EU')

# %%
df1819Clean = df1819Clean.merge(df_Code_Info, how="inner", on="code")

# %%
df1819Clean.dtypes
# Out:
# date         object
# time         object
# day          object
# station      object
# code         object
# min_delay     int64
# min_gap       int64
# bound        object
# line         object
# vehicle       int64
# id            int64
# code_info    object
# dtype: object

# %%
len(df1819Clean)
# Out:
# 13694

# %%
df1819Clean.head()
# Out:
#          date   time       day                station   code  min_delay  \
# 0  2019-01-01  03:03   Tuesday         DUPONT STATION  MUATC         11
# 1  2019-01-01  16:02   Tuesday         DUPONT STATION  MUATC          6
# 2  2019-01-07  15:22    Monday      GLENCAIRN STATION  MUATC          5
# 3  2019-01-10  15:41  Thursday         DUPONT STATION  MUATC          4
# 4  2019-01-11  02:11    Friday  EGLINTON WEST STATION  MUATC          5
#
#    min_gap bound line  vehicle   id    code_info
# 0       16     N   YU     6061    1  ATC Project
# 1       10     N   YU     6081   16  ATC Project
# 2        8     S   YU     6131  103  ATC Project
# 3        7     N   YU     5466  165  ATC Project
# 4       10     N   YU     5806  171  ATC Project

# %%
df_Lat_Long = pd.read_excel('LookUp_Lat_Long.xlsx')
df_Lat_Long.head()
# Out:
#                    station   latitude  longitude
# 0       VAUGHAN MC STATION  43.794167 -79.527500
# 1      HIGHWAY 407 STATION  43.783889 -79.523056
# 2  PIONEER VILLAGE STATION  43.776944 -79.509444
# 3  YORK UNIVERSITY STATION  43.774167 -79.499722
# 4       FINCH WEST STATION  43.765278 -79.491111

# %%
df1819Clean = df1819Clean.merge(df_Lat_Long,on="station")
df1819Clean.head()
# Out:
#          date   time        day         station   code  min_delay  min_gap  \
# 0  2019-01-01  03:03    Tuesday  DUPONT STATION  MUATC         11       16
# 1  2019-01-01  16:02    Tuesday  DUPONT STATION  MUATC          6       10
# 2  2019-01-10  15:41   Thursday  DUPONT STATION  MUATC          4        7
# 3  2019-01-14  09:05     Monday  DUPONT STATION  MUATC          5        7
# 4  2019-01-16  09:00  Wednesday  DUPONT STATION  MUATC          4        6
#
#   bound line  vehicle   id    code_info   latitude  longitude
# 0     N   YU     6061    1  ATC Project  43.674584  -79.40683
# 1     N   YU     6081   16  ATC Project  43.674584  -79.40683
# 2     N   YU     5466  165  ATC Project  43.674584  -79.40683
# 3     N   YU     5656  230  ATC Project  43.674584  -79.40683
# 4     N   YU     5656  266  ATC Project  43.674584  -79.40683

# %%
df1819Clean.dtypes
# Out:
# date          object
# time          object
# day           object
# station       object
# code          object
# min_delay      int64
# min_gap        int64
# bound         object
# line          object
# vehicle        int64
# id             int64
# code_info     object
# latitude     float64
# longitude    float64
# dtype: object

# %%
df_Line_Name = pd.read_excel('LookUp_Line.xlsx')
df_Line_Name.head()
# Out:
#   line                 line_name
# 0   YU  Yonge University Spadina
# 1   BD            Bloor Danforth
# 2  SRT  Scarborough Rail Transit
# 3  SHP                  Sheppard

# %%
df1819Clean = df1819Clean.merge(df_Line_Name,on="line")
df1819Clean.head()
# Out:
#          date   time        day         station   code  min_delay  min_gap  \
# 0  2019-01-01  03:03    Tuesday  DUPONT STATION  MUATC         11       16
# 1  2019-01-01  16:02    Tuesday  DUPONT STATION  MUATC          6       10
# 2  2019-01-10  15:41   Thursday  DUPONT STATION  MUATC          4        7
# 3  2019-01-14  09:05     Monday  DUPONT STATION  MUATC          5        7
# 4  2019-01-16  09:00  Wednesday  DUPONT STATION  MUATC          4        6
#
#   bound line  vehicle   id    code_info   latitude  longitude  \
# 0     N   YU     6061    1  ATC Project  43.674584  -79.40683
# 1     N   YU     6081   16  ATC Project  43.674584  -79.40683
# 2     N   YU     5466  165  ATC Project  43.674584  -79.40683
# 3     N   YU     5656  230  ATC Project  43.674584  -79.40683
# 4     N   YU     5656  266  ATC Project  43.674584  -79.40683
#
#                   line_name
# 0  Yonge University Spadina
# 1  Yonge University Spadina
# 2  Yonge University Spadina
# ...

# %%
import datetime
tempdate = pd.to_datetime(df1819Clean['date'])
df1819Clean['month'] = tempdate.dt.month_name(locale = 'English')
#df1819Clean['month_number'] = pd.DatetimeIndex(df1819Clean['date']).month
df1819Clean['month_number'] = tempdate.dt.month
df1819Clean['year'] = tempdate.dt.year
df1819Clean.head()
# Out:
#          date   time        day         station   code  min_delay  min_gap  \
# 0  2019-01-01  03:03    Tuesday  DUPONT STATION  MUATC         11       16
# 1  2019-01-01  16:02    Tuesday  DUPONT STATION  MUATC          6       10
# 2  2019-01-10  15:41   Thursday  DUPONT STATION  MUATC          4        7
# 3  2019-01-14  09:05     Monday  DUPONT STATION  MUATC          5        7
# 4  2019-01-16  09:00  Wednesday  DUPONT STATION  MUATC          4        6
#
#   bound line  vehicle   id    code_info   latitude  longitude  \
# 0     N   YU     6061    1  ATC Project  43.674584  -79.40683
# 1     N   YU     6081   16  ATC Project  43.674584  -79.40683
# 2     N   YU     5466  165  ATC Project  43.674584  -79.40683
# 3     N   YU     5656  230  ATC Project  43.674584  -79.40683
# 4     N   YU     5656  266  ATC Project  43.674584  -79.40683
#
#                   line_name    month  month_number  year
# 0  Yonge University Spadina  January             1  2019
# ...

# %%
#other method
#df1819Clean['year'] = pd.DatetimeIndex(df1819Clean['date']).year

# %%
temphour = pd.to_datetime(df1819Clean['time'])
df1819Clean['hour'] = temphour.dt.hour
df1819Clean.head()
# Out:
#          date   time        day         station   code  min_delay  min_gap  \
# 0  2019-01-01  03:03    Tuesday  DUPONT STATION  MUATC         11       16
# 1  2019-01-01  16:02    Tuesday  DUPONT STATION  MUATC          6       10
# 2  2019-01-10  15:41   Thursday  DUPONT STATION  MUATC          4        7
# 3  2019-01-14  09:05     Monday  DUPONT STATION  MUATC          5        7
# 4  2019-01-16  09:00  Wednesday  DUPONT STATION  MUATC          4        6
#
#   bound line  vehicle   id    code_info   latitude  longitude  \
# 0     N   YU     6061    1  ATC Project  43.674584  -79.40683
# 1     N   YU     6081   16  ATC Project  43.674584  -79.40683
# 2     N   YU     5466  165  ATC Project  43.674584  -79.40683
# 3     N   YU     5656  230  ATC Project  43.674584  -79.40683
# 4     N   YU     5656  266  ATC Project  43.674584  -79.40683
#
#                   line_name    month  month_number  year  hour
# 0  Yonge University Spadina  January             1  2019     3
# ...

# %%
# Create the bins in which Data will be held 
bins = [0, 5, 9, 12, 15, 18, 23]

# Create the names for the four bins
group_names = ["9PM-1:30AM", "5-9AM", "9AM-12PM", "12-3PM", "3-6PM","6-9PM"]

# %%
df1819Clean["time_range"] = pd.cut(df1819Clean["hour"], bins, labels=group_names)
df1819Clean.head()
# Out:
#          date   time        day         station   code  min_delay  min_gap  \
# 0  2019-01-01  03:03    Tuesday  DUPONT STATION  MUATC         11       16
# 1  2019-01-01  16:02    Tuesday  DUPONT STATION  MUATC          6       10
# 2  2019-01-10  15:41   Thursday  DUPONT STATION  MUATC          4        7
# 3  2019-01-14  09:05     Monday  DUPONT STATION  MUATC          5        7
# 4  2019-01-16  09:00  Wednesday  DUPONT STATION  MUATC          4        6
#
#   bound line  vehicle   id    code_info   latitude  longitude  \
# 0     N   YU     6061    1  ATC Project  43.674584  -79.40683
# 1     N   YU     6081   16  ATC Project  43.674584  -79.40683
# 2     N   YU     5466  165  ATC Project  43.674584  -79.40683
# 3     N   YU     5656  230  ATC Project  43.674584  -79.40683
# 4     N   YU     5656  266  ATC Project  43.674584  -79.40683
#
#                   line_name    month  month_number  year  hour  time_range
# ...

# %%
df1819Clean.shape
# Out:
# (13694, 20)

# %%
df1819Clean
# Out:
#              date   time        day                station   code  min_delay  \
# 0      2019-01-01  03:03    Tuesday         DUPONT STATION  MUATC         11
# 1      2019-01-01  16:02    Tuesday         DUPONT STATION  MUATC          6
# 2      2019-01-10  15:41   Thursday         DUPONT STATION  MUATC          4
# 3      2019-01-14  09:05     Monday         DUPONT STATION  MUATC          5
# 4      2019-01-16  09:00  Wednesday         DUPONT STATION  MUATC          4
# 5      2019-01-19  01:55   Saturday         DUPONT STATION  MUATC          4
# 6      2019-01-20  17:44     Sunday         DUPONT STATION  MUATC          9
# 7      2019-01-25  01:46     Friday         DUPONT STATION  MUATC          5
# 8      2019-01-27  10:12     Sunday         DUPONT STATION  MUATC          8
# 9      2019-02-04  06:36     Monday         DUPONT STATION  MUATC          6
# 10     2019-02-04  06:51     Monday         DUPONT STATION  MUATC          4
# ...

# %%
df1819Clean.sort_values('id', inplace = True, ascending=True)
df1819Clean.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-421abea1d2e3> in <module>
#       1 df1819Clean.sort_values('id', inplace = True, ascending=True)
# ----> 2 df1819Clean.columns()
#
# TypeError: 'Index' object is not callable

# %%
df1819Final = df1819Clean[['id', 'date', 'time', 'day', 'station', 'code', 'min_delay', 'min_gap',
       'bound', 'line', 'vehicle', 'code_info', 'latitude', 'longitude',
       'line_name', 'month', 'time_range', 'month_number', 'hour', 'year']]
df1819Final.head()
# Out:
#       id        date   time      day                station   code  min_delay  \
# 0      1  2019-01-01  03:03  Tuesday         DUPONT STATION  MUATC         11
# 269    2  2019-01-01  03:08  Tuesday  EGLINTON WEST STATION  EUATC         11
# 53     3  2019-01-01  03:09  Tuesday         DUPONT STATION  EUATC          6
# 1035   4  2019-01-01  03:26  Tuesday  ST CLAIR WEST STATION  EUATC          4
# 5765   5  2019-01-01  08:04  Tuesday     DAVISVILLE STATION  MUNOA          5
#
#       min_gap bound line  vehicle  \
# 0          16     N   YU     6061
# 269        16     S   YU     5656
# 53         11     N   YU     5381
# 1035        9     N   YU     5571
# 5765       10     S   YU        0
#
#                                               code_info   latitude  longitude  \
# 0                                           ATC Project  43.674584 -79.406830
# 269                                  ATC RC&S Equipment  43.699209 -79.435819
# ...

# %%
df1819Final.to_csv('ttc_subway_delay_2018_2019_from_pandas.csv', index=False)

# %%
len(df1819Final)
# Out:
# 13694

# %%
df1819Final.nunique()
# Out:
# id              13694
# date              730
# time             1279
# day                 7
# station            80
# code              177
# min_delay         114
# min_gap           125
# bound               5
# line                4
# vehicle           636
# code_info         134
# latitude           74
# longitude          76
# line_name           4
# month              12
# time_range          6
# month_number       12
# hour               24
# year                2
# dtype: int64
