# %%
import pandas as pd
import numpy as np

# %%
df1819 = pd.read_csv('ttc_subway_delay_2018_2019.csv')
len(df1819)
# Out:
# 13727

# %%
df1819.dtypes
# Out:
# id                int64
# date             object
# time             object
# day              object
# station          object
# code             object
# min_delay         int64
# min_gap           int64
# bound            object
# line             object
# vehicle           int64
# code_info        object
# latitude        float64
# longitude       float64
# line_name        object
# month            object
# time_range       object
# month_number      int64
# hour              int64
# year              int64
# dtype: object

# %%
df1819.head()
# Out:
#    id        date  time      day                station   code  min_delay  \
# 0   1  2019-01-01  3:03  Tuesday         DUPONT STATION  MUATC         11
# 1   2  2019-01-01  3:08  Tuesday  EGLINTON WEST STATION  EUATC         11
# 2   3  2019-01-01  3:09  Tuesday         DUPONT STATION  EUATC          6
# 3   4  2019-01-01  3:26  Tuesday  ST CLAIR WEST STATION  EUATC          4
# 4   5  2019-01-01  8:04  Tuesday     DAVISVILLE STATION  MUNOA          5
#
#    min_gap bound line  vehicle  \
# 0       16     N   YU     6061
# 1       16     S   YU     5656
# 2       11     N   YU     5381
# 3        9     N   YU     5571
# 4       10     S   YU        0
#
#                                            code_info   latitude  longitude  \
# 0                                        ATC Project  43.674584 -79.406830
# 1                                 ATC RC&S Equipment  43.699209 -79.435819
# 2                                 ATC RC&S Equipment  43.674584 -79.406830
# ...

# %%
dfstation = pd.read_excel('station_sort.xlsx')
dfstation
# Out:
#     Unnamed: 0                     station                          Sort
# 0            0          VAUGHAN MC STATION           0VAUGHAN MC STATION
# 1            1         HIGHWAY 407 STATION          1HIGHWAY 407 STATION
# 2            2      PIONEER VILLAGE STATIO       2PIONEER VILLAGE STATIO
# 3            3      YORK UNIVERSITY STATIO       3YORK UNIVERSITY STATIO
# 4            4          FINCH WEST STATION           4FINCH WEST STATION
# 5            5      DOWNSVIEW PARK STATION       5DOWNSVIEW PARK STATION
# 6            6       SHEPPARD WEST STATION        6SHEPPARD WEST STATION
# 7            7              WILSON STATION               7WILSON STATION
# 8            8            YORKDALE STATION             8YORKDALE STATION
# 9            9       LAWRENCE WEST STATION        9LAWRENCE WEST STATION
# 10          10           GLENCAIRN STATION           10GLENCAIRN STATION
# 11          11       EGLINTON WEST STATION       11EGLINTON WEST STATION
# ...

# %%
df18 = df1819.loc[(df1819['year'] == 2018)]
len(df18)
# Out:
# 7049

# %%
FailingDrugs = []

# %%
for x in range(5):

# %%
df19 = df1819.loc[(df1819['year'] == 2019)]
len(df19)
# Out:
# 6678

# %%
grouped_df18 = df18.groupby("station")
average18 = grouped_df18["min_delay"].mean()
amount18 = grouped_df18["min_delay"].count()

# %%
grouped_df19 = df19.groupby("station")
average19 = grouped_df19["min_delay"].mean()
amount19 = grouped_df19["min_delay"].count()
