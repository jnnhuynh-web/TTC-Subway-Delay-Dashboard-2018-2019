# %%
# Dependencies
import pandas as pd

# %%
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect

# %%
engine = create_engine('postgres://root:root1234@my-postgres-db.cxwwjsronhkv.ca-central-1.rds.amazonaws.com:5432/postgres')

# %%
# Store filepath in a variable
file_one = "../Data/ttc_subway_delay_2018_2019.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
subway_data_df = pd.read_csv(file_one, encoding="ISO-8859-1")
subway_data_df.head()
# Out:
#    id        date  time      day                station   code  min_delay  \
# 0   1  2019-01-01  3:03  Tuesday         DUPONT STATION  MUATC         11
# 1   2  2019-01-01  3:08  Tuesday  EGLINTON WEST STATION  EUATC         11
# 2   3  2019-01-01  3:09  Tuesday         DUPONT STATION  EUATC          6
# 3   4  2019-01-01  3:26  Tuesday  ST CLAIR WEST STATION  EUATC          4
# 4   5  2019-01-01  8:04  Tuesday     DAVISVILLE STATION  MUNOA          5
#
#    min_gap bound line  vehicle  \
# 0       16     N   YU     6061
# 1       16     S   YU     5656
# 2       11     N   YU     5381
# 3        9     N   YU     5571
# 4       10     S   YU        0
#
#                                            code_info   latitude   longitude  \
# 0                                        ATC Project  43.674584   -79.40683
# 1                                 ATC RC&S Equipment  43.699209  -79.435819
# 2                                 ATC RC&S Equipment  43.674584   -79.40683
# ...

# %%
len(subway_data_df)
# Out:
# 13732

# %%
subway_data_df.to_sql('ttc_subway_detail', con=engine, if_exists='replace', index=False)

# %%
engine.execute('ALTER TABLE ttc_subway_detail ADD PRIMARY KEY (id);')

# %%
#Check if table is loaded
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['ttc_subway_detail', 'stations_in_line']

# %%
test_df=pd.read_sql('SELECT * FROM ttc_subway_detail;', engine)
test_df
# Out:
#           id        date   time        day                     station   code  \
# 0          1  2019-01-01   3:03    Tuesday              DUPONT STATION  MUATC
# 1          2  2019-01-01   3:08    Tuesday       EGLINTON WEST STATION  EUATC
# 2          3  2019-01-01   3:09    Tuesday              DUPONT STATION  EUATC
# 3          4  2019-01-01   3:26    Tuesday       ST CLAIR WEST STATION  EUATC
# 4          5  2019-01-01   8:04    Tuesday          DAVISVILLE STATION  MUNOA
# 5          6  2019-01-01   8:07    Tuesday               KEELE STATION  MUESA
# 6          7  2019-01-01   8:09    Tuesday            DONLANDS STATION  MUESA
# 7          8  2019-01-01   8:09    Tuesday             KIPLING STATION  MUESA
# 8          9  2019-01-01   8:18    Tuesday            DONLANDS STATION  MUESA
# 9         10  2019-01-01   8:18    Tuesday            DONLANDS STATION  MUESA
# 10        11  2019-01-01   8:19    Tuesday          KENNEDY BD STATION  MUESA
# ...

# %%
# Store filepath in a variable
file_two = "../Data/station_in_line_2018_2019.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
stations_data_df = pd.read_csv(file_two, encoding="ISO-8859-1")
stations_data_df.head()
# Out:
#    Unnamed: 0                 station   latitude     longitude  \
# 0           0      VAUGHAN MC STATION  43.794167      -79.5275
# 1           1     HIGHWAY 407 STATION  43.783889    -79.523056
# 2           2  PIONEER VILLAGE STATIO  43.776944    -79.509444
# 3           3  YORK UNIVERSITY STATIO  43.774167  Â -79.499722
# 4           4      FINCH WEST STATION  43.765278    -79.491111
#
#                   line_name  avg_delay_time_2019  num_delays_2019  id  \
# 0  Yonge University Spadina                 4.92              241   1
# 1  Yonge University Spadina                 6.13               24   2
# 2  Yonge University Spadina                14.05               20   3
# 3  Yonge University Spadina                 5.29               21   4
# 4  Yonge University Spadina                 6.58               31   5
#
#    avg_delay_time_2018  num_delays_2018
# 0                 5.48              250
# 1                 9.58               19
# 2                 6.21               24
# ...

# %%
len(stations_data_df)
# Out:
# 80

# %%
stations_data_df.to_sql('stations_in_line', con=engine, if_exists='replace', index=False)

# %%
engine.execute('ALTER TABLE stations_in_line ADD PRIMARY KEY (id);')

# %%
stations_aws_df=pd.read_sql('SELECT * FROM stations_in_line;', engine)
stations_aws_df
# Out:
#     Unnamed: 0                     station   latitude     longitude  \
# 0            0          VAUGHAN MC STATION  43.794167      -79.5275
# 1            1         HIGHWAY 407 STATION  43.783889    -79.523056
# 2            2      PIONEER VILLAGE STATIO  43.776944    -79.509444
# 3            3      YORK UNIVERSITY STATIO  43.774167  Â -79.499722
# 4            4          FINCH WEST STATION  43.765278    -79.491111
# ..         ...                         ...        ...           ...
# 75          75  SHEPPARD-YONGE SHP STATION  43.761389    -79.410833
# 76          76             BAYVIEW STATION  43.766944    -79.386667
# 77          77           BESSARION STATION  43.769167    -79.376389
# 78          78              LESLIE STATION  43.771389    -79.365278
# 79          79           DON MILLS STATION  43.775556    -79.346389
#
#                    line_name  avg_delay_time_2019  num_delays_2019  id  \
# 0   Yonge University Spadina                 4.92              241   1
# ...
